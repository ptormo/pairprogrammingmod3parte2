# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df_ventas = pd.read_csv("ventas.csv") 
df_ventas
# Out:
#     ID_Cliente ID_Producto Fecha_Venta  Cantidad  Total
# 0          723          A1  2023-11-22         2  17.98
# 1          498          C3  2023-11-21         1   5.49
# 2          121          D4  2023-11-20         3  32.97
# 3          885         L12  2023-11-19         1   6.49
# 4          347         Q17  2023-11-18         2   7.98
# ..         ...         ...         ...       ...    ...
# 95         234       AR136  2023-09-04         1   8.45
# 96         987       AS137  2023-09-03         2  12.50
# 97         543       AT138  2023-09-02         1   4.75
# 98         234       AU139  2023-09-01         2   9.98
# 99         987       AV140  2023-08-31         1   5.25
#
# [100 rows x 5 columns]

# %%
df_products = pd.read_csv("productos.csv") 
df_products
# Out:
#       ID                 Nombre_Producto             Categoría  Precio  \
# 0     A1                Pizza Margherita     Platos Preparados    8.99
# 1     B2          Risotto de Champiñones     Platos Preparados    6.75
# 2     C3                        Tiramisú               Postres    5.49
# 3     D4                       Panettone            Repostería   10.99
# 4     E5                     Orecchiette       Productos Secos    4.29
# 5     F6             Polenta Tradicional               Harinas    3.75
# 6     G7            Mozzarella di Bufala     Productos Lácteos    9.25
# 7     H8                  Pesto Genovese                Salsas    5.99
# 8     I9               Lasagna Bolognesa     Platos Preparados    7.49
# 9    J10                   Arroz Arborio       Productos Secos    4.89
# 10   K11                   Café Espresso                  Café    6.49
# 11   L12     Sardinas en Aceite de Oliva  Pescados en Conserva    3.99
# ...

# %%
df_products.rename(columns={'ID': 'ID_Producto'}, inplace=True)

# %%
df_products
# Out:
#    ID_Producto                 Nombre_Producto             Categoría  Precio  \
# 0           A1                Pizza Margherita     Platos Preparados    8.99
# 1           B2          Risotto de Champiñones     Platos Preparados    6.75
# 2           C3                        Tiramisú               Postres    5.49
# 3           D4                       Panettone            Repostería   10.99
# 4           E5                     Orecchiette       Productos Secos    4.29
# 5           F6             Polenta Tradicional               Harinas    3.75
# 6           G7            Mozzarella di Bufala     Productos Lácteos    9.25
# 7           H8                  Pesto Genovese                Salsas    5.99
# 8           I9               Lasagna Bolognesa     Platos Preparados    7.49
# 9          J10                   Arroz Arborio       Productos Secos    4.89
# 10         K11                   Café Espresso                  Café    6.49
# ...

# %%
df_clients = pd.read_csv("clientes.csv") 
df_clients
# Out:
#        id  first_name last_name                         email  gender  \
# 0       1       Cheri  Dunsmore      cdunsmore0@instagram.com  Female
# 1       2        Hunt  Bartomeu         hbartomeu1@nsw.gov.au    Male
# 2       3  Michaeline   Paynton            mpaynton2@narod.ru  Female
# 3       4      Filmer    Eirwin            feirwin3@intel.com     NaN
# 4       5      Tanhya   Lubbock  tlubbock4@huffingtonpost.com  Female
# ..    ...         ...       ...                           ...     ...
# 995   996         Ray    Tarpey      rtarpeyrn@bravesites.com  Female
# 996   997        Flem  Roderham       froderhamro@dropbox.com    Male
# 997   998   Winifield    Blakes         wblakesrp@jiathis.com    Male
# 998   999      Lanita  Espinosa        lespinosarq@discuz.net  Female
# 999  1000     Grissel   Siberry     gsiberryrr@wikispaces.com  Female
#
#                             City Country                   Address
# ...

# %%
df_clients['id']=df_clients['id'].replace(df_ventas['ID_Cliente'])

# %%
df_clients.rename(columns={'id': 'ID_Clientes'}, inplace=True)

# %%
df_clients['id'] = df_clients['ID_Clientes']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\PC\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ID_Clientes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df_clients['id'] = df_clients['ID_Clientes']
#
# ...

# %%
df_clients
# Out:
#      ID_Clientes  first_name last_name                         email  gender  \
# 0            498       Cheri  Dunsmore      cdunsmore0@instagram.com  Female
# 1            121        Hunt  Bartomeu         hbartomeu1@nsw.gov.au    Male
# 2            885  Michaeline   Paynton            mpaynton2@narod.ru  Female
# 3            347      Filmer    Eirwin            feirwin3@intel.com     NaN
# 4            619      Tanhya   Lubbock  tlubbock4@huffingtonpost.com  Female
# ..           ...         ...       ...                           ...     ...
# 995          996         Ray    Tarpey      rtarpeyrn@bravesites.com  Female
# 996          997        Flem  Roderham       froderhamro@dropbox.com    Male
# 997          998   Winifield    Blakes         wblakesrp@jiathis.com    Male
# 998          999      Lanita  Espinosa        lespinosarq@discuz.net  Female
# 999         1000     Grissel   Siberry     gsiberryrr@wikispaces.com  Female
#
# ...
